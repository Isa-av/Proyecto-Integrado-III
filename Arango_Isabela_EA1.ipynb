# %% [markdown]
# # S20 - Evidencia de Aprendizaje 1
#
# Proyecto Integrado III - Analítica de Datos (Andrés Felipe Palacio) - PREICA2601B020046
#
# Por: Isabela Arango Verona
#
# Abril del 2026

# %% [markdown]
# ## Importación de librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Perfilamiento de Datos

# %%
import kagglehub
import os

# Descargar el dataset
path = kagglehub.dataset_download("hamnamunir/social-media-user-behavior-dataset")

# Ver qué archivos hay en esa ruta
archivos = os.listdir(path)
print("Archivos disponibles:", archivos)

# Cargar el CSV
csv_path = os.path.join(path, archivos[0])
df = pd.read_csv(csv_path)

df.head()
# Out:
# Downloading to /root/.cache/kagglehub/datasets/hamnamunir/social-media-user-behavior-dataset/2.archive...
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 812kB/s]
# Extracting files...
# Archivos disponibles: ['social_media_user_behavior.csv', 'README.md', 'dataset-metadata.json']
#     user_id  age             gender   country    profession primary_platform  \
# 0  USR00001   30             Female        UK        Doctor         Facebook
# 1  USR00002   25               Male       USA  Entrepreneur        Instagram
# 2  USR00003   32               Male       UAE    Freelancer           TikTok
# 3  USR00004   39  Prefer not to say  Pakistan         Other           TikTok
# 4  USR00005   25               Male        UK         Other          YouTube
#
#    platforms_used_count  daily_usage_hours  sessions_per_day  \
# 0                     1                1.6                 2
# 1                     2                2.4                 5
# 2                     5                0.5                 6
# 3                     4                3.0                 7
# 4                     3                3.9                 7
#
#    avg_session_duration_min  ... primary_purpose sleep_disruption  \
# 0                      48.0  ...   Entertainment        No impact
# 1                      28.8  ...  News & Updates  Moderate impact
# 2                       5.0  ...        Learning      Mild impact
# 3                      25.7  ...   Entertainment      Mild impact
# 4                      33.4  ...   Entertainment      Mild impact
#
#    self_reported_mental_health_score  screen_time_concern  \
# 0                                3.9                   No
# 1                                4.2                   No
# 2                                4.8                  Yes
# 3                                7.9             Somewhat
# 4                                6.5                   No
#
#    notification_frequency  privacy_setting  influencer_status  \
# 0          Do Not Disturb     Friends Only                 No
# 1                Selected           Public                 No
# 2               Always On     Friends Only                 No
# 3               Always On           Public                Yes
# 4          Do Not Disturb           Public                 No
#
#    account_join_date  mood_while_scrolling takes_social_media_breaks
# 0         2022-10-21               Neutral                        No
# 1         2024-12-03               Neutral                       Yes
# 2         2023-03-29                 Happy                       Yes
# 3         2024-04-26                 Happy                        No
# 4         2023-09-08              Inspired                        No
#
# [5 rows x 34 columns]

# %% [markdown]
# Perfilado de Datos

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

from ydata_profiling import ProfileReport

# Generar el perfil
profile = ProfileReport(df, title="Análisis de Comportamiento en Redes Sociales", explorative=True)

# Guardar como HTML para descargar
profile.to_file("exploracion_datos.html")
# Out:
# Collecting https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Using cached https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy<1.17,>=1.8 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (2.12.3)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /usr/local/lib/python3.12/dist-packages (from visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling==0.0.dev0) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (2.0.2)
# Requirement already satisfied: minify-html>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (2.32.4)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (4.67.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (4.5.1)
# Requirement already satisfied: imagehash==4.3.2 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in /usr/local/lib/python3.12/dist-packages (from fg-data-profiling==0.0.dev0) (0.60.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.12/dist-packages (from imagehash==4.3.2->fg-data-profiling==0.0.dev0) (1.9.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from imagehash==4.3.2->fg-data-profiling==0.0.dev0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<3.2,>=3.1.6->fg-data-profiling==0.0.dev0) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling==0.0.dev0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling==0.0.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling==0.0.dev0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling==0.0.dev0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling==0.0.dev0) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling==0.0.dev0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->fg-data-profiling==0.0.dev0) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba<0.63,>=0.60->fg-data-profiling==0.0.dev0) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.4.0,<3.0,>1.5->fg-data-profiling==0.0.dev0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.4.0,<3.0,>1.5->fg-data-profiling==0.0.dev0) (2026.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from phik<0.13,>=0.12.5->fg-data-profiling==0.0.dev0) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->fg-data-profiling==0.0.dev0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->fg-data-profiling==0.0.dev0) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->fg-data-profiling==0.0.dev0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->fg-data-profiling==0.0.dev0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->fg-data-profiling==0.0.dev0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->fg-data-profiling==0.0.dev0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->fg-data-profiling==0.0.dev0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->fg-data-profiling==0.0.dev0) (2026.2.25)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels<1,>=0.13.2->fg-data-profiling==0.0.dev0) (1.0.2)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.12/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling==0.0.dev0) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.12/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling==0.0.dev0) (3.6.1)
# Requirement already satisfied: puremagic in /usr/local/lib/python3.12/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->fg-data-profiling==0.0.dev0) (2.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->fg-data-profiling==0.0.dev0) (1.17.0)
# /tmp/ipykernel_14972/4030527196.py:3: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
#   3%|▎         | 1/34 [00:00<00:03,  8.98it/s]
#  24%|██▎       | 8/34 [00:00<00:00, 39.64it/s]
#  38%|███▊      | 13/34 [00:00<00:00, 39.83it/s]
#  59%|█████▉    | 20/34 [00:00<00:00, 48.53it/s]
#  74%|███████▎  | 25/34 [00:00<00:00, 42.20it/s]
# 100%|██████████| 34/34 [00:00<00:00, 40.65it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# Nota: La exploración de los datos se encuentra en el informe de la tarea.
